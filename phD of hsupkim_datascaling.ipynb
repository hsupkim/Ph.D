# %%
from google.colab import drive
drive.mount('/content/drive')

# Navigate to the root directory of your Google Drive
# %cd /content/drive/MyDrive/

# Open and display the scatter_matrix.png file
from PIL import Image
im = Image.open('/content/drive/MyDrive/scatter_matrix_D.png')
im.show()

# %%
filepath = '/content/drive/My Drive/input_MD.csv'
dfMD = pd.read_csv(filepath)
dfMD.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0          5689578           288450       256711513        14592819
# 1         12703384           557396       107853229        46474202
# 2          6865030          3782295        32999591        83662594
# 3          7302403           508963        37978047       666504990
# 4        189180232           671240         8259448        12281261
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_input=dfMD.iloc[:,13:].to_numpy()
dfMD_target=dfMD['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_input, dfMD_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.6296296296296297

# %%
from sklearn.preprocessing import MinMaxScaler

# 4. MinMax transformation
scaler = MinMaxScaler()
dfMD[dfMD.columns[13:]] = scaler.fit_transform(dfMD[dfMD.columns[13:]])

# Save the transformed data to a new .csv file
dfMD.to_csv("dfMD_MM.csv", index=False)

dfMD_MM = pd.read_csv("dfMD_MM.csv")
dfMD_MM.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0         0.003366         0.020053        0.856459        0.017729
# 1         0.014509         0.082919        0.355120        0.065766
# 2         0.005233         0.836746        0.103021        0.121800
# 3         0.005928         0.071598        0.119788        1.000000
# 4         0.294885         0.109531        0.019699        0.014246
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_MM_input=dfMD_MM.iloc[:,13:].to_numpy()
dfMD_MM_target=dfMD_MM['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_MM_input, dfMD_MM_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7407407407407407

# %%
from sklearn.preprocessing import StandardScaler

# 4. Standard transformation
scaler = StandardScaler()
dfMD[dfMD.columns[13:]] = scaler.fit_transform(dfMD[dfMD.columns[13:]])

# Save the transformed data to a new .csv file
dfMD.to_csv("dfMD_ST.csv", index=False)

dfMD_ST = pd.read_csv("dfMD_ST.csv")
dfMD_ST.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        -0.717776        -0.670973        2.940400       -0.229982
# 1        -0.654201        -0.276563        0.901981        0.393563
# 2        -0.707121         4.452752       -0.123041        1.120903
# 3        -0.703157        -0.347590       -0.054867       12.520291
# 4         0.945434        -0.109611       -0.461824       -0.275192
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_ST_input=dfMD_ST.iloc[:,13:].to_numpy()
dfMD_ST_target=dfMD_ST['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_ST_input, dfMD_ST_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7407407407407407

# %%
from sklearn.preprocessing import RobustScaler

# 4. Robust transformation
scaler = RobustScaler()
dfMD[dfMD.columns[13:]] = scaler.fit_transform(dfMD[dfMD.columns[13:]])

# Save the transformed data to a new .csv file
dfMD.to_csv("dfMD_RB.csv", index=False)

dfMD_RB = pd.read_csv("dfMD_RB.csv")
dfMD_RB.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        -0.236236        -0.441241        6.287144       -0.049647
# 1        -0.176539         0.080770        2.508935        1.260332
# 2        -0.226232         6.340133        0.609056        2.788372
# 3        -0.222509        -0.013236        0.735416       26.736877
# 4         1.325520         0.301735       -0.018879       -0.144627
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_RB_input=dfMD_RB.iloc[:,13:].to_numpy()
dfMD_RB_target=dfMD_RB['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_RB_input, dfMD_RB_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7592592592592593

# %%
# Subtract the mean of each column and divide by the square of the standard deviation of each column
dfMD.iloc[:, 13:] = (dfMD.iloc[:, 13:] - dfMD.iloc[:, 13:].mean()) / dfMD.iloc[:, 13:].std()**0.5

# Move the first column (sample name) and second column (group name) to the front and combine the data
cols = dfMD.columns.tolist()
cols = cols[:13] + cols[13:]
dfMD = dfMD[cols]
dfMD.to_csv("dfMD_PR.csv", index=False)
dfMD_PR = pd.read_csv("dfMD_PR.csv")
dfMD_PR.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        -7.251575        -3.589465       28.213139       -2.110509
# 1        -6.609286        -1.479516        8.654513        3.611668
# 2        -7.143933        23.820630       -1.180575       10.286365
# 3        -7.103880        -1.859485       -0.526451      114.896863
# 4         9.551568        -0.586381       -4.431205       -2.525395
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_PR_input=dfMD_PR.iloc[:,13:].to_numpy()
dfMD_PR_target=dfMD_PR['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_PR_input, dfMD_PR_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7777777777777778

# %%
filepath = '/content/drive/My Drive/input_MD.csv'
dfMD = pd.read_csv(filepath)
# Log transform the data
dfMD[dfMD.columns[13:]] = np.log(dfMD[dfMD.columns[13:]])
    
# Save the transformed data to a new .csv file
dfMD.to_csv("dfMD_log.csv", index=False)

dfMD_log = pd.read_csv("dfMD_log.csv")
dfMD_log.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        15.554147        12.572277       19.363463       16.496040
# 1        16.357379        13.231031       18.496282       17.654408
# 2        15.741951        15.145842       17.312006       18.242303
# 3        15.803714        13.140131       17.452519       20.317558
# 4        19.058211        13.416882       15.926868       16.323585
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_log_input=dfMD_log.iloc[:,13:].to_numpy()
dfMD_log_target=dfMD_log['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_log_input, dfMD_log_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.8703703703703703

# %%
from sklearn.preprocessing import MinMaxScaler

# 4. MinMax transformation
scaler = MinMaxScaler()
dfMD_log[dfMD_log.columns[13:]] = scaler.fit_transform(dfMD_log[dfMD_log.columns[13:]])

# Save the transformed data to a new .csv file
dfMD_log.to_csv("dfMD_log_MM.csv", index=False)

dfMD_log_MM = pd.read_csv("dfMD_log_MM.csv")
dfMD_log_MM.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0         0.089958         0.114010        0.968144        0.300463
# 1         0.245094         0.326787        0.788296        0.512505
# 2         0.126230         0.945268        0.542685        0.620120
# 3         0.138159         0.297426        0.571827        1.000000
# 4         0.766732         0.386816        0.255416        0.268895
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_log_MM_input=dfMD_log_MM.iloc[:,13:].to_numpy()
dfMD_log_MM_target=dfMD_log_MM['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_log_MM_input, dfMD_log_MM_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.8518518518518519

# %%
from sklearn.preprocessing import StandardScaler

# 4. Standard transformation
scaler = StandardScaler()
dfMD_log[dfMD_log.columns[13:]] = scaler.fit_transform(dfMD_log[dfMD_log.columns[13:]])

# Save the transformed data to a new .csv file
dfMD_log.to_csv("dfMD_log_ST.csv", index=False)

dfMD_log_ST = pd.read_csv("dfMD_log_ST.csv")
dfMD_log_ST.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        -1.434222        -1.042317        2.023264        0.063280
# 1        -0.822334        -0.048160        1.440972        1.127316
# 2        -1.291156         2.841572        0.645760        1.667336
# 3        -1.244106        -0.185342        0.740111        3.573593
# 4         1.235111         0.232317       -0.284326       -0.095132
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_log_ST_input=dfMD_log_ST.iloc[:,13:].to_numpy()
dfMD_log_ST_target=dfMD_log_ST['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_log_ST_input, dfMD_log_ST_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.8703703703703703

# %%
from sklearn.preprocessing import RobustScaler

# 4. Robust transformation
scaler = RobustScaler()
dfMD_log[dfMD_log.columns[13:]] = scaler.fit_transform(dfMD_log[dfMD_log.columns[13:]])

# Save the transformed data to a new .csv file
dfMD_log.to_csv("dfMD_log_RB.csv", index=False)

dfMD_log_RB = pd.read_csv("dfMD_log_RB.csv")
dfMD_log_RB.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        -0.729199        -0.622167        1.311430       -0.043627
# 1        -0.398403         0.083065        0.971990        0.591663
# 2        -0.651855         2.132976        0.508430        0.914086
# 3        -0.626419        -0.014249        0.563431        2.052231
# 4         0.713884         0.282029       -0.033753       -0.138208
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_log_RB_input=dfMD_log_RB.iloc[:,13:].to_numpy()
dfMD_log_RB_target=dfMD_log_RB['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_RB_input, dfMD_RB_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7592592592592593

# %%
# Subtract the mean of each column and divide by the square of the standard deviation of each column
dfMD_log.iloc[:, 13:] = (dfMD_log.iloc[:, 13:] - dfMD_log.iloc[:, 13:].mean()) / dfMD_log.iloc[:, 13:].std()**0.5

# Move the first column (sample name) and second column (group name) to the front and combine the data
cols = dfMD_log.columns.tolist()
cols = cols[:13] + cols[13:]
dfMD_log = dfMD_log[cols]
dfMD.to_csv("dfMD_log_PR.csv", index=False)
dfMD_log_PR = pd.read_csv("dfMD_log_PR.csv")
dfMD_log_PR.head()
# Out:
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0        15.554147        12.572277       19.363463       16.496040
# 1        16.357379        13.231031       18.496282       17.654408
# 2        15.741951        15.145842       17.312006       18.242303
# 3        15.803714        13.140131       17.452519       20.317558
# 4        19.058211        13.416882       15.926868       16.323585
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
dfMD_log_PR_input=dfMD_log_PR.iloc[:,13:].to_numpy()
dfMD_log_PR_target=dfMD_log_PR['class2'].to_numpy()

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(dfMD_PR_input, dfMD_PR_target, random_state=42)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=20, max_iter=1000)
lr.fit(train_input, train_target)
print("Train Accuracy:", lr.score(train_input, train_target))
print("Test Accuracy:", lr.score(test_input, test_target))
# Out:
# 1.0
# 0.7777777777777778
