# %%
from google.colab import drive
drive.mount('/content/drive')

from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

filepath = '/content/drive/My Drive/input_M.csv'
dfM = pd.read_csv(filepath)
dfM.head()
# Out:
# Mounted at /content/drive
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  M1(3)     M1      M    Mar  M_Mar  1.0  12.8  2.8  2.278  0.013  ...
# 1  M1(4)     M1      M    Apr  M_Apr  1.2  11.3  3.2  2.342  0.006  ...
# 2  M1(5)     M1      M    May  M_May  1.2  10.7  3.2  1.326  0.004  ...
# 3  M1(6)     M1      M    Jun  M_Jun  1.2   9.7  3.1  1.670  0.008  ...
# 4  M1(7)     M1      M    Jul  M_Jul  1.2   9.3  3.3  1.926  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0          5689578           288450       256711513        14592819
# 1         12703384           557396       107853229        46474202
# 2          6865030          3782295        32999591        83662594
# 3          7302403           508963        37978047       666504990
# 4        189180232           671240         8259448        12281261
#
#    C10 H10 O2(1/2)  C10 H10 O2(2/2)  C10 H10 O3(1/3)  C10 H10 O3(2/3)  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
corr_matrix=dfM.corr()

# %%
top_corr = corr_matrix["COD"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["COD"].sort_values(ascending=True)[:12]
print(top_corr)
print(bottom_corr)
# Out:
# COD                  1.000000
# BOD                  0.660127
# C9 H12 N2 O2(2/2)    0.596512
# C9 H11 N O(2/2)      0.573534
# C17 H17 Cl O         0.549472
# C7 H14 F N O2 S      0.545866
# C10 H13 N3 O2        0.542287
# C12 H14 N4 O3 S      0.540906
# C21 H15 N3 O2        0.538715
# C9 H12 N2 O(1/2)     0.533357
# C14 H19 N O4(3/3)    0.531235
# C10 H11 N O3(3/3)    0.521821
# Name: COD, dtype: float64
# pH                   -0.549710
# DO                   -0.451286
# C16 H25 N O3(4/4)    -0.420063
# C13 H15 F3 O(1/2)    -0.407065
# C8 H5 F9 O3          -0.396647
# C7 H8 I N3           -0.385581
# C16 H21 N3           -0.379841
# C15 H19 N3(2/3)      -0.378773
# C12 H11 F3 O3(2/2)   -0.374516
# C5 H10 Cl N O2       -0.372676
# C12 H16 Br N O2      -0.365520
# C15 H18 F3 N         -0.355371
# Name: COD, dtype: float64

# %%
top_corr = corr_matrix["BOD"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["BOD"].sort_values(ascending=True)[:11]
print(top_corr)
print(bottom_corr)
# Out:
# BOD                  1.000000
# COD                  0.660127
# C15 H28 O7           0.585580
# C13 H20 N2 O(2/2)    0.580315
# C24 H51 N O5 P S     0.576773
# C22 H39 N5 O5        0.571740
# C28 H31 F N4 O       0.570140
# C7 H9 N3             0.568230
# C8 H10 N4 O2(2/3)    0.562580
# C27 H54 O11          0.557666
# C24 H30 O5(3/3)      0.557311
# C6 H7 N5(2/2)        0.556365
# Name: BOD, dtype: float64
# C8 H5 F9 O3          -0.447692
# C7 H4 Cl2 N O2       -0.433119
# C45 H63 N3 O3(1/2)   -0.430617
# C14 H8 Cl4 O3        -0.429179
# C9 H9 Br O           -0.426782
# C7 H8 I N3           -0.424887
# H3 Bi O3             -0.419761
# C9 H9 F3 O S         -0.414861
# C10 H5 Br Cl N3      -0.410399
# C6 H7 Br S           -0.410225
# pH                   -0.410127
# Name: BOD, dtype: float64

# %%
top_corr = corr_matrix["T-N"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["T-N"].sort_values(ascending=True)[:11]
print(top_corr)
print(bottom_corr)
# Out:
# T-N                  1.000000
# C4 H2 Cl4 O          0.843529
# C10 H4 Br2 N2 Se     0.833995
# C13 H2 Cl6 O2        0.829421
# C6 H2 Br Cl3 O2 S    0.817679
# C4 H11 N5            0.797177
# C8 H13 F3 O2         0.790721
# C4 H6 Cl4 O2 S5      0.779464
# C8 H14 N4 O2(1/2)    0.776355
# C8 H4 Cl I O3 S      0.770826
# C9 H21 N O4          0.761904
# C6 H2 Br2 Cl2 O      0.760829
# Name: T-N, dtype: float64
# C8 H9 Br O2           -0.537639
# C12 H4 N4 S6          -0.522019
# C10 H6 Br Cl N2 O2    -0.499727
# C7 H7 I O             -0.494746
# C8 H11 Br S           -0.494682
# C10 H11 N3 O S(2/2)   -0.493902
# C8 H4 Br F3 O3        -0.488991
# C12 H10 O2 Se2        -0.483330
# C7 H7 Br O S          -0.463081
# C6 H Cl F4 S          -0.458665
# C6 H5 I O4 S          -0.457526
# Name: T-N, dtype: float64

# %%
top_corr = corr_matrix["T-P"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["T-P"].sort_values(ascending=True)[:11]
print(top_corr)
print(bottom_corr)
# Out:
# T-P                         1.000000
# C6 H7 I O2 S2               0.439943
# SS                          0.430562
# C20 H17 Br N2 O2            0.406874
# C8 H8 Cl3 P S2              0.404150
# C8 H5 Br Cl I O             0.403634
# C15 H17 Cl2 N3 O2(2/2)      0.402567
# C8 H4 Br2 N2 O3             0.398574
# C18 H14 Br Cl2 N5 O2        0.396646
# C20 H11 Cl I N3 O3          0.390924
# C12 H17 Br Cl F2 N3 O6 S    0.386225
# C12 H8 I2 S2                0.373446
# Name: T-P, dtype: float64
# C12 H16 Br N O2     -0.235076
# C25 H47 N S         -0.232658
# C18 H31 N3 O4       -0.228827
# C16 H31 N O(2/3)    -0.228450
# pH                  -0.224530
# C18 H33 N O7        -0.223228
# C26 H45 N O4(1/2)   -0.222434
# C14 H31 N           -0.221268
# C12 H27 N(2/3)      -0.219817
# C30 H24 N4 O3       -0.219501
# C9 H10 I N O2 S     -0.217821
# Name: T-P, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes=["COD","BOD","T-N","T-P","C9 H12 N2 O2(2/2)","C16 H25 N O3(4/4)","C15 H28 O7","C8 H5 F9 O3","C4 H2 Cl4 O","C8 H9 Br O2","C6 H7 I O2 S2","C12 H16 Br N O2"]
# scatter_matrix(df[attributes], figsize=(22,25))
scatter_matrix_obj = scatter_matrix(df[attributes], figsize=(22,25))
for ax in scatter_matrix_obj.flatten():
    ax.set_xlabel(ax.get_xlabel(), fontsize=10)
    ax.set_ylabel(ax.get_ylabel(), fontsize=10)
    ax.tick_params(axis='both', which='both', length=0, width=0)
    ax.set_xticklabels([])
    ax.set_yticklabels([])

plt.savefig("scatter_matrix_M.png")

# %%
from google.colab import drive
drive.mount('/content/drive')

from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

filepath = '/content/drive/My Drive/input_D.csv'
dfD = pd.read_csv(filepath)
dfD.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Name class1 class2 class3 class4  BOD    DO  COD    T-N    T-P  ...  \
# 0  D1(3)     D1      D    Mar  D_Mar  0.5  12.2  3.3  2.093  0.020  ...
# 1  D1(4)     D1      D    Apr  D_Apr  0.6  11.4  3.4  1.778  0.020  ...
# 2  D1(5)     D1      D    May  D_May  0.9  10.1  3.5  1.643  0.009  ...
# 3  D1(6)     D1      D    Jun  D_Jun  1.3   9.1  3.7  1.667  0.015  ...
# 4  D1(7)     D1      D    Jul  D_Jul  1.4   8.3  4.4  1.419  0.014  ...
#
#    C10 H10 N4 O2 S  C10 H10 N4 O3 S  C10 H10 O(1/2)  C10 H10 O(2/2)  \
# 0          5766334           343140       299331943        19082236
# 1         12641386           455371       120168095        46404218
# 2          6432549          2104827        40167168        98571841
# 3          7744337           600364        46952838        35409156
# ...

# %%
corr_matrix=dfD.corr()

# %%
top_corr = corr_matrix["COD"].sort_values(ascending=False)[:13]
bottom_corr = corr_matrix["COD"].sort_values(ascending=True)[:10]
print(top_corr)
print(bottom_corr)
# Out:
# COD                  1.000000
# BOD                  0.763317
# C12 H7 F2 N3         0.535119
# T-P                  0.519642
# C7 H9 N3             0.485467
# C7 H12 N2 O2(1/2)    0.473218
# C9 H12 N2 O2(2/2)    0.469394
# C15 H21 N O4(3/4)    0.466342
# C14 H19 N O2(2/2)    0.463944
# C7 H13 N3 O3         0.459719
# C9 H8 N2 O2          0.450550
# C6 H11 N3 O2         0.450444
# C14 H19 N O4(2/3)    0.446060
# Name: COD, dtype: float64
# C14 H23 N3 O4       -0.369373
# C15 H18 F3 N        -0.368955
# C13 H15 F3 O(1/2)   -0.350179
# C5 H12 As2 N2       -0.343041
# C20 H42 N O3 P      -0.340767
# C14 H8 Cl4 O3       -0.333003
# C8 H5 F9 O3         -0.318548
# C16 H25 N O3(4/4)   -0.312638
# C9 H9 F3 O S        -0.306080
# C5 H10 Cl N O2      -0.305801
# Name: COD, dtype: float64

# %%
top_corr = corr_matrix["BOD"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["BOD"].sort_values(ascending=True)[:10]
print(top_corr)
print(bottom_corr)
# Out:
# BOD                    1.000000
# COD                    0.763317
# C8 H12 N2 O3           0.590259
# C14 H18 N2 O4(1/3)     0.557443
# C13 H19 N O2(4/5)      0.545971
# C12 H7 F2 N3           0.527196
# C7 H13 N3 O3           0.525377
# C15 H18 N2 O3(1/2)     0.515929
# C8 H14 N2 O3(1/2)      0.513429
# C7 H7 N3(2/2)          0.489430
# C6 H11 N3 O2           0.484070
# C13 H17 N O4 S(2/2)    0.482391
# Name: BOD, dtype: float64
# H3 Bi O3          -0.461938
# C9 H9 F3 O S      -0.461315
# C8 H5 F9 O3       -0.430857
# C5 H12 As2 N2     -0.425111
# C12 H16 Br N O2   -0.424610
# C9 H10 I N O2 S   -0.415191
# C14 H8 Cl4 O3     -0.404624
# C10 H11 Br O4 S   -0.387806
# C10 H5 Br Cl N3   -0.386802
# C14 H8 Cl4 S      -0.384973
# Name: BOD, dtype: float64

# %%
top_corr = corr_matrix["T-N"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["T-N"].sort_values(ascending=True)[:10]
print(top_corr)
print(bottom_corr)
# Out:
# T-N                  1.000000
# C7 H10 N2 O2(2/2)    0.675592
# C19 H17 F N2 O3      0.643762
# C8 H12 N2 O3         0.633305
# C8 H19 N O3          0.628713
# C7 H4 N2 S5          0.601040
# C9 H9 Br2 N O        0.599867
# C8 H14 N2 O3(1/2)    0.593465
# C21 H23 N3 O3 S      0.582155
# C9 H5 B N O          0.565161
# C5 H2 Cl2 F4 O2      0.559980
# C2 H2 B Cl3          0.555988
# Name: T-N, dtype: float64
# C16 H17 F3 O3        -0.550051
# C14 H7 Cl2 D4 N O2   -0.538380
# C17 H12 Br2          -0.532815
# C19 H11 D5 O4        -0.526498
# C31 H60 O4           -0.520127
# C16 H20 O2(2/2)      -0.516665
# C15 H5 Br Cl2 N4     -0.513911
# C9 H15 N5 O4         -0.513816
# C10 H11 I O2(1/2)    -0.512227
# C23 H47 N O          -0.510513
# Name: T-N, dtype: float64

# %%
top_corr = corr_matrix["T-P"].sort_values(ascending=False)[:12]
bottom_corr = corr_matrix["T-P"].sort_values(ascending=True)[:12]
print(top_corr)
print(bottom_corr)
# Out:
# T-P                     1.000000
# SS                      0.744130
# C12 H20 N2 O3           0.724001
# C11 H11 Cl N2 O(3/3)    0.670821
# C12 H14 N4 O4 S2        0.667818
# C36 H36 Cl3 N O6        0.651916
# C26 H52 O8 Si8          0.632326
# C14 H14 F6 N2 O3        0.631173
# C26 H50 O2(1/2)         0.618684
# C24 H46 O4(1/3)         0.604019
# C37 H69 N O5 Si2        0.601699
# C51 H51 N15 O15 S       0.599668
# Name: T-P, dtype: float64
# DO                   -0.308949
# C14 H31 N O3(1/2)    -0.290435
# C21 H32 N6 O9        -0.288027
# pH                   -0.278819
# C18 H31 N O3(2/4)    -0.267481
# C12 H15 N3 O3(1/3)   -0.260198
# C14 H20 O3(2/4)      -0.257009
# C17 H26 O5(2/7)      -0.250372
# C17 H36 N2 O6(1/2)   -0.249524
# C5 H8 Cl2 Si(2/2)    -0.248946
# C41 H63 N O14(2/2)   -0.245410
# C11 H22 O2 S         -0.244802
# Name: T-P, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes=["COD","BOD","T-N","T-P","C12 H7 F2 N3","C14 H23 N3 O4","C8 H12 N2 O3","H3 Bi O3","C7 H10 N2 O2(2/2)","C16 H17 F3 O3","C12 H20 N2 O3","C14 H31 N O3(1/2)"]
# scatter_matrix(df[attributes], figsize=(22,25))
scatter_matrix_obj = scatter_matrix(df[attributes], figsize=(22,25))
for ax in scatter_matrix_obj.flatten():
    ax.set_xlabel(ax.get_xlabel(), fontsize=10)
    ax.set_ylabel(ax.get_ylabel(), fontsize=10)
    ax.tick_params(axis='both', which='both', length=0, width=0)
    ax.set_xticklabels([])
    ax.set_yticklabels([])

plt.savefig("scatter_matrix_D.png")
